# %%
#Transfer learning - resnet152V2 .ipynb

# import packages
import cv2
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import numpy as np

#load model # Accuracy=99.3 , validation Accuracy = 99.3 # heavy model, size =226MB
model_res = load_model('model/resnet152v2_acc_vacc_99_3.h5') #resnet transfer learning

# model accept below hight and width of the image
img_width, img_hight = 224, 224

# %% [markdown]
# # or

# %%
#Own cnn  architecture - mask detection CNN.ipynb

# import packages
import cv2
from keras.models import load_model
from keras.preprocessing.image import load_img, img_to_array
import numpy as np

#load model # Accuracy=97.4 , validation Accuracy = 99.1 # very light model, size =5MB
model = load_model('model/model_acc_974_vacc_991.h5') # cnn

# model accept below hight and width of the image
img_width, img_hight = 200, 200

# %%
# Load the Cascade face Classifier
face_cascade = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")

#startt  web cam
#cap = cv2.VideoCapture(0) # for webcam
cap = cv2.VideoCapture('videos/Mask - 34775.mp4') # for video

img_count_full = 0

#parameters for text
# font 
font = cv2.FONT_HERSHEY_SIMPLEX 
# org 
org = (1, 1)
class_lable=' '      
# fontScale 
fontScale = 1 #0.5
# Blue color in BGR 
color = (255, 0, 0) 
# Line thickness of 2 px 
thickness = 2 #1

#sart reading images and prediction
while True:
    img_count_full += 1
    
    #read image from webcam
    #responce, color_img = cap.read()
    color_img = cv2.imread('sandeep.jpg')
    
    # if respoce False the break the loop
    #if responce == False:
        #break    
    

    #resize image with 50 % ratio
    scale = 50  
    width = int(color_img.shape[1] * scale / 100)  
    height = int(color_img.shape[0] * scale / 100)  
    dim = (width, height)  
    # resize image  
    color_img = cv2.resize(color_img, dim, interpolation=cv2.INTER_AREA) 
    
    
    # Convert to grayscale
    gray_img = cv2.cvtColor(color_img, cv2.COLOR_BGR2GRAY)
    
    # Detect the faces
    faces = face_cascade.detectMultiScale(gray_img, 1.1, 6) # 1.1, 3) for 1.mp4
    
    #take face then predict class mask or not mask then draw recrangle and text then display image
    img_count = 0
    for (x, y, w, h) in faces:
        org = (x-10,y-10)
        img_count +=1 
        color_face = color_img[y:y+h,x:x+w] # color face
        cv2.imwrite('faces/input/%d%dface.jpg'%(img_count_full,img_count),color_face)
        img = load_img('faces/input/%d%dface.jpg'%(img_count_full,img_count), target_size=(img_width,img_hight))
        
        img = img_to_array(img)/255
        img = np.expand_dims(img,axis=0)
        pred_prob = model.predict(img)
        #print(pred_prob[0][0].round(2))
        pred=np.argmax(pred_prob)
            
        if pred==0:
            print("User with mask - predic = ",pred_prob[0][0])
            class_lable = "Mask"
            color = (255, 0, 0)
            cv2.imwrite('faces/with_mask/%d%dface.jpg'%(img_count_full,img_count),color_face)
                 
        else:
            print('user not wearing mask - prob = ',pred_prob[0][1])
            class_lable = "No Mask"
            color = (0, 255, 0)
            cv2.imwrite('faces/without_mask/%d%dface.jpg'%(img_count_full,img_count),color_face)
                
        cv2.rectangle(color_img, (x, y), (x+w, y+h), (0, 0, 255), 3)
        # Using cv2.putText() method 
        cv2.putText(color_img, class_lable, org, font,  
                                   fontScale, color, thickness, cv2.LINE_AA) 
    
    # display image
    cv2.imshow('LIVE face mask detection', color_img)
    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the VideoCapture object
cap.release()
cv2.destroyAllWindows()
# Out:
# user not wearing mask - prob =  0.99974865
# user not wearing mask - prob =  0.9998568
# user not wearing mask - prob =  0.99993956
# user not wearing mask - prob =  0.9998307
# user not wearing mask - prob =  0.9995758
# user not wearing mask - prob =  0.99925333
# user not wearing mask - prob =  0.9968219
# user not wearing mask - prob =  0.9498141
# user not wearing mask - prob =  0.8791716
# User with mask - predic =  0.6545871
# User with mask - predic =  0.97565347
# User with mask - predic =  0.882785
# User with mask - predic =  0.9650494
# User with mask - predic =  0.99227625
# User with mask - predic =  0.9900331
# User with mask - predic =  0.98442876
# User with mask - predic =  0.9922117
# User with mask - predic =  0.9907534
# User with mask - predic =  0.9822472
# User with mask - predic =  0.9811281
# User with mask - predic =  0.9692787
# User with mask - predic =  0.96521443
# User with mask - predic =  0.97650695
# User with mask - predic =  0.9810167
# User with mask - predic =  0.88595825
# User with mask - predic =  0.8361249
# User with mask - predic =  0.75729537
# User with mask - predic =  0.54201984
# user not wearing mask - prob =  0.59247535
# user not wearing mask - prob =  0.5786998
# user not wearing mask - prob =  0.6941625
# user not wearing mask - prob =  0.6054347
# User with mask - predic =  0.5494942
# User with mask - predic =  0.59859335
# User with mask - predic =  0.82053006
# User with mask - predic =  0.9074556
# User with mask - predic =  0.88215095
# User with mask - predic =  0.9009819
# User with mask - predic =  0.90036577
# User with mask - predic =  0.91137844
# User with mask - predic =  0.9144101
# User with mask - predic =  0.7659283
# User with mask - predic =  0.6064158
# User with mask - predic =  0.77294683
# User with mask - predic =  0.65084434
# User with mask - predic =  0.6808513
# User with mask - predic =  0.79927623
# User with mask - predic =  0.7073835
# User with mask - predic =  0.76036084
# User with mask - predic =  0.73498553
# User with mask - predic =  0.81523395
# User with mask - predic =  0.62783927
# User with mask - predic =  0.81919456
# User with mask - predic =  0.7138593
# User with mask - predic =  0.5195078
# User with mask - predic =  0.699093
# User with mask - predic =  0.6039691
# User with mask - predic =  0.9194401
# User with mask - predic =  0.93698317
# User with mask - predic =  0.90355694
# User with mask - predic =  0.8652402
# User with mask - predic =  0.91498846
# User with mask - predic =  0.930143
# User with mask - predic =  0.74531823
# User with mask - predic =  0.7401569
# User with mask - predic =  0.9536689
# User with mask - predic =  0.9981218
# User with mask - predic =  0.99874413
# User with mask - predic =  0.9993123
# User with mask - predic =  0.9994203
# User with mask - predic =  0.9992391
# User with mask - predic =  0.9993549
# User with mask - predic =  0.99938655
# User with mask - predic =  0.9993907
# User with mask - predic =  0.99933004
# User with mask - predic =  0.9994092
# User with mask - predic =  0.99927944
# User with mask - predic =  0.99922454
# User with mask - predic =  0.9990663
# User with mask - predic =  0.9990089
# User with mask - predic =  0.9990771
# User with mask - predic =  0.9991379
# User with mask - predic =  0.99873537
# User with mask - predic =  0.99882954
# User with mask - predic =  0.99703825
# User with mask - predic =  0.99810505
# User with mask - predic =  0.99855095
# User with mask - predic =  0.9993356
# User with mask - predic =  0.99920964
# User with mask - predic =  0.9996075
# User with mask - predic =  0.9995473
# User with mask - predic =  0.9995117
# User with mask - predic =  0.99915266
# User with mask - predic =  0.9987827
# User with mask - predic =  0.99865675
# User with mask - predic =  0.9994692
# User with mask - predic =  0.99917907
# User with mask - predic =  0.99890184
# User with mask - predic =  0.998703
# User with mask - predic =  0.9991196
# User with mask - predic =  0.9995807
# User with mask - predic =  0.9997267
# User with mask - predic =  0.9997168
# User with mask - predic =  0.9994168
# User with mask - predic =  0.9996487
# User with mask - predic =  0.9994547
# User with mask - predic =  0.9996666
# User with mask - predic =  0.9993616
# User with mask - predic =  0.99928206
# User with mask - predic =  0.9991736
# User with mask - predic =  0.9987043
# User with mask - predic =  0.9989882
# User with mask - predic =  0.9981396
